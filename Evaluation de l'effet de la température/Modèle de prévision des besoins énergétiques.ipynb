# %% [markdown]
# # Modèle de prévision des besoins énergétiques

# %% [markdown]
# ## Mise en place de l'environnement de travail

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import pmdarima as pm

# %% [markdown]
# ## Chargement des données

# %%
cuiseur2 = pd.read_csv('Cuiseur 2 (1).csv', sep=';')
cuiseur2.head()
# Out:
#                   CLML  Cuiseur2PMP_J  Cuiseur2PSF_J  Cuiseur2Ratio_MP_J  \
# 0  01/12/2021 00:00:00            NaN            NaN                 NaN
# 1  02/12/2021 00:00:00            NaN            NaN                 NaN
# 2  03/12/2021 00:00:00            NaN            NaN                 NaN
# 3  04/12/2021 00:00:00            NaN            NaN                 NaN
# 4  05/12/2021 00:00:00            NaN            NaN                 NaN
#
#    Cuiseur2Ratio_PSF_J  Cuiseur2Tonne_J
# 0                  NaN             87.4
# 1                  NaN             61.1
# 2                  NaN             49.4
# 3                  NaN             32.0
# 4                  NaN              1.1

# %%
Temp = pd.read_csv('Temperature_meteo.csv')
Temp.head()
# Out:
#    location         Bâle       Bâle.1       Bâle.2
# 0       lat     47.75000     47.75000     47.75000
# 1       lon      7.50000      7.50000      7.50000
# 2       asl      363.653      363.653      363.653
# 3  variable  Temperature  Temperature  Temperature
# 4      unit           °C           °C           °C

# %% [markdown]
# ## Préparation des données

# %% [markdown]
# ### Préparation des données du cuiseur

# %% [markdown]
# #### Extraction des données utilisables

# %%
c2 = pd.DataFrame()
c2 = cuiseur2[cuiseur2.index>184]
c2.head()
# Out:
#                     CLML  Cuiseur2PMP_J  Cuiseur2PSF_J  Cuiseur2Ratio_MP_J  \
# 185  08/06/2022 00:00:00         35.126         16.636            4.989118
# 186  09/06/2022 00:00:00         81.613         42.924            0.567312
# 187  10/06/2022 00:00:00         71.433         31.186            0.669030
# 188  11/06/2022 00:00:00         72.700         28.854            0.680712
# 189  12/06/2022 00:00:00         33.198         11.516            0.528097
#
#      Cuiseur2Ratio_PSF_J  Cuiseur2Tonne_J
# 185            10.777577             51.2
# 186             1.078651             46.3
# 187             1.548435             46.3
# 188             1.583836             48.9
# 189             1.543686             16.7

# %% [markdown]
# #### Création d'un nouveau DataFrame avec uniquement le ratio

# %%
Ratio = pd.DataFrame()
Ratio['Temps'] = c2['CLML']
Ratio['Values'] = c2['Cuiseur2Ratio_MP_J']
Ratio.reset_index(drop=True, inplace=True)
Ratio.head()
# Out:
#                  Temps    Values
# 0  08/06/2022 00:00:00  4.989118
# 1  09/06/2022 00:00:00  0.567312
# 2  10/06/2022 00:00:00  0.669030
# 3  11/06/2022 00:00:00  0.680712
# 4  12/06/2022 00:00:00  0.528097

# %% [markdown]
# #### Identification et traitement des valeurs manquantes

# %%
print(Ratio['Values'].median())
# Out:
# 0.685

# %%
p = Ratio.loc[Ratio['Values'].isnull()]
p
# Out:
#                    Temps  Values
# 38   16/07/2022 00:00:00     NaN
# 39   17/07/2022 00:00:00     NaN
# 40   18/07/2022 00:00:00     NaN
# 116  02/10/2022 00:00:00     NaN
# 159  14/11/2022 00:00:00     NaN
# 160  15/11/2022 00:00:00     NaN
# 214  08/01/2023 00:00:00     NaN
# 254  17/02/2023 00:00:00     NaN
# 255  18/02/2023 00:00:00     NaN
# 256  19/02/2023 00:00:00     NaN
# 257  20/02/2023 00:00:00     NaN
# 258  21/02/2023 00:00:00     NaN
# 291  26/03/2023 00:00:00     NaN
# 305  09/04/2023 00:00:00     NaN
# 437  19/08/2023 00:00:00     NaN
# 438  20/08/2023 00:00:00     NaN
# 508  29/10/2023 00:00:00     NaN
# 521  11/11/2023 00:00:00     NaN
# 522  12/11/2023 00:00:00     NaN
# 523  13/11/2023 00:00:00     NaN

# %%
Ratio.fillna(method='ffill', axis='index', inplace=True)
print(Ratio.isnull().sum())
# Out:
# Values    0
# dtype: int64

# %%
Ratio.set_index('Temps', inplace=True)
Ratio.index = pd.to_datetime(Ratio.index, format='%d/%m/%Y %H:%M:%S')
Ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 671 entries, 2022-06-08 to 2024-04-08
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Values  651 non-null    float64
# dtypes: float64(1)
# memory usage: 10.5 KB

# %% [markdown]
# #### Visualisations de la série exemptée des valeurs manquantes

# %%
plt.figure(figsize=(14,6))
plt.plot(Ratio)
plt.xlabel('Dates')
plt.ylabel('Ratio')
plt.show()

# %% [markdown]
# #### Imputation des valeurs aberrantes et visualisation finale de notre dataset

# %%
Ratio.loc[Ratio['Values'] > 19 ] = Ratio['Values'].median()

# %%
plt.figure(figsize=(14,6))
plt.plot(Ratio)
plt.xlabel('Dates')
plt.ylabel('Ratio')
plt.show()

# %% [markdown]
# #### Vérification de la stationnarité de notre série

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(Ratio)
print('Test statistic : ', result[0])
print('P-value : ', result[1])
if (result[1]<0.05):
    print('Votre série est stationnaire')
# Out:
# Test statistic :  -9.069655609449626
# P-value :  4.336757683642701e-15
# Votre série est stationnaire

# %% [markdown]
# Puisque la série stationnaire, nous pouvons conclure que notre série ne présente pas de motifs en tendance et en saisonnalité.

# %% [markdown]
# #### Train-Test split de nos données

# %%
train = Ratio.loc[Ratio.index < '26/11/2023 00:00:00']
test = Ratio.loc[Ratio.index >= '26/11/2023 00:00:00']

plt.figure(figsize=(14,6))
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.xlabel('Dates')
plt.ylabel('Ratio')
plt.title('Data Train-Test Split')
plt.legend()
plt.show()

# %% [markdown]
# ### Préparation des données des températures de Nabeul

# %% [markdown]
# ####  Extraction des températures

# %%
Temp = Temp.iloc[Temp.index>8,:]
Temp.head()
# Out:
#          location       Bâle     Bâle.1     Bâle.2
# 9   20220608T0000  22.060246  11.350245  16.360245
# 10  20220609T0000  18.690245  11.770246  15.875245
# 11  20220610T0000  24.800245   8.400246  17.516493
# 12  20220611T0000  28.410246  11.430245   20.63733
# 13  20220612T0000  30.760244  12.620245  22.341078

# %% [markdown]
# #### Création d'un nouveau dataframe contenant uniquement les températures moyennes par jour

# %%
Tj = pd.DataFrame()
Tj['Date'] = Temp['location']
Tj['Temperature'] = Temp['Bâle.2']
Tj.head()
# Out:
#              Date Temperature
# 9   20220608T0000   16.360245
# 10  20220609T0000   15.875245
# 11  20220610T0000   17.516493
# 12  20220611T0000    20.63733
# 13  20220612T0000   22.341078

# %%
Tj.set_index('Date', inplace=True)
Tj.index = pd.to_datetime(Tj.index)
Tj.head()
# Out:
#            Temperature
# Date
# 2022-06-08   16.360245
# 2022-06-09   15.875245
# 2022-06-10   17.516493
# 2022-06-11    20.63733
# 2022-06-12   22.341078

# %% [markdown]
# ## Choix des paramètres du modèle

# %% [markdown]
# ### Visualisation du graphe ACF et du graphe PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(train, lags=20)
plt.xlabel('Décalages')
plt.ylabel('Corrélations')
plt.show()

# %%
plot_pacf(train, lags=20, method='ywm')
plt.xlabel('Décalages')
plt.ylabel('Corrélations')
plt.show()

# %% [markdown]
# Suite à la visualisation des graphes ACF et PACF, nous fixons p et q à 6.

# %% [markdown]
# ## Entraînement de notre modèle

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

ARMA_model = SARIMAX(train, order=(8,0,1), seasonal_periods=(0,0,0,0))
ARMA_result = ARMA_model.fit()

print(ARMA_result.summary())
# Out:
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(8, 0, 1)   Log Likelihood                -976.761
# Date:                Sun, 19 May 2024   AIC                           1973.523
# Time:                        21:01:51   BIC                           2016.364
# Sample:                    06-08-2022   HQIC                          1990.283
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1543      0.031     36.678      0.000       1.093       1.216
# ar.L2         -0.1133      0.076     -1.495      0.135      -0.262       0.035
# ar.L3         -0.0330      0.086     -0.384      0.701      -0.202       0.135
# ar.L4         -0.0410      0.119     -0.346      0.730      -0.273       0.191
# ar.L5         -0.0297      0.124     -0.240      0.810      -0.273       0.213
# ar.L6          0.2210      0.083      2.659      0.008       0.058       0.384
# ar.L7         -0.1634      0.068     -2.401      0.016      -0.297      -0.030
# ar.L8          0.0051      0.054      0.095      0.924      -0.101       0.111
# ma.L1         -0.9953      0.012    -83.260      0.000      -1.019      -0.972
# sigma2         2.2249      0.055     40.286      0.000       2.117       2.333
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             27986.41
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             4.67
# Prob(H) (two-sided):                  0.49   Kurtosis:                        37.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = pd.DataFrame(ARMA_result.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Résidues", ax=ax[0])
residuals.plot(kind='kde', title='Densité', ax=ax[1])
plt.show()

# %% [markdown]
# Puisque toutes nos p-valeurs sont non significatives, nous allons procéder à une optimisation automatique de nos paramètres.

# %%
Auto_arma_model = pm.auto_arima(train, start_p=1, start_q=1, test='adf', max_p=6, max_q=6, m=1, d=None, D=0, trace=True, stepwise=True, suppress_warnings=True)
print(Auto_arma_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1970.451, Time=0.51 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1979.915, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1969.098, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1970.182, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2211.953, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1970.392, Time=0.17 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1972.390, Time=0.33 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=2091.224, Time=0.09 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 2.234 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  536
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -981.549
# Date:                Sun, 19 May 2024   AIC                           1969.098
# Time:                        19:26:18   BIC                           1981.950
# Sample:                    06-08-2022   HQIC                          1974.126
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9573      0.117      8.210      0.000       0.729       1.186
# ar.L1          0.1545      0.020      7.876      0.000       0.116       0.193
# sigma2         2.2809      0.050     45.624      0.000       2.183       2.379
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):             35799.01
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             5.02
# Prob(H) (two-sided):                  0.43   Kurtosis:                        41.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
Auto_arma_model.plot_diagnostics(figsize=(14,6))
plt.show()

# %%
def rmse(test_df,pred):
    error = np.array(test_df)-pred.values
    rmse = np.sqrt((error**2).mean())
    return rmse

# %%
def training(test_df):
    for i in range(1,9):
        for j in range(1,9):
            ARMA_model = SARIMAX(train, order=(i,0,j), seasonal_periods=(0,0,0,0))
            ARMA_result = ARMA_model.fit()
            print(ARMA_result.summary())
            pred = ARMA_result.predict(start=test_df.index[0], end=test_df.index[-1])
            r = rmse(test_df,pred)
            print('La rmse du modèle ARMA(',i,',',j,') est : ', r)

# %%
training(test)
# Out:
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -990.168
# Date:                Fri, 17 May 2024   AIC                           1986.336
# Time:                        22:18:59   BIC                           1999.189
# Sample:                    06-08-2022   HQIC                          1991.364
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9997      0.000   2523.175      0.000       0.999       1.001
# ma.L1         -0.9823      0.011    -85.731      0.000      -1.005      -0.960
# sigma2         2.3430      0.039     60.766      0.000       2.267       2.419
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.12   Jarque-Bera (JB):             35514.61
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                             5.14
# Prob(H) (two-sided):                  0.95   Kurtosis:                        41.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 1 ,) est :  0.8247946114496574
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 2)   Log Likelihood                -984.898
# Date:                Fri, 17 May 2024   AIC                           1977.796
# Time:                        22:19:00   BIC                           1994.932
# Sample:                    06-08-2022   HQIC                          1984.500
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   4264.602      0.000       0.999       1.000
# ma.L1         -0.8525      0.022    -39.614      0.000      -0.895      -0.810
# ma.L2         -0.1364      0.023     -6.054      0.000      -0.181      -0.092
# sigma2         2.2958      0.035     65.783      0.000       2.227       2.364
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             35147.24
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             5.02
# Prob(H) (two-sided):                  0.53   Kurtosis:                        41.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 2 ,) est :  0.8229466093642009
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 3)   Log Likelihood                -984.217
# Date:                Fri, 17 May 2024   AIC                           1978.434
# Time:                        22:19:01   BIC                           1999.855
# Sample:                    06-08-2022   HQIC                          1986.814
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   4963.502      0.000       1.000       1.000
# ma.L1         -0.8486      0.027    -31.800      0.000      -0.901      -0.796
# ma.L2         -0.0907      0.063     -1.435      0.151      -0.215       0.033
# ma.L3         -0.0513      0.044     -1.164      0.244      -0.138       0.035
# sigma2         2.2896      0.034     68.038      0.000       2.224       2.356
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             35302.58
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             5.01
# Prob(H) (two-sided):                  0.46   Kurtosis:                        41.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 3 ,) est :  0.8171752512860846
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 4)   Log Likelihood                -984.011
# Date:                Fri, 17 May 2024   AIC                           1980.022
# Time:                        22:19:02   BIC                           2005.727
# Sample:                    06-08-2022   HQIC                          1990.079
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   5392.979      0.000       1.000       1.000
# ma.L1         -0.8461      0.027    -31.925      0.000      -0.898      -0.794
# ma.L2         -0.0837      0.062     -1.360      0.174      -0.204       0.037
# ma.L3         -0.0356      0.074     -0.480      0.631      -0.181       0.110
# ma.L4         -0.0262      0.061     -0.432      0.665      -0.145       0.092
# sigma2         2.2875      0.033     68.405      0.000       2.222       2.353
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             35476.60
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             5.00
# Prob(H) (two-sided):                  0.45   Kurtosis:                        41.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 4 ,) est :  0.812759973512942
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 5)   Log Likelihood                -983.883
# Date:                Fri, 17 May 2024   AIC                           1981.766
# Time:                        22:19:03   BIC                           2011.754
# Sample:                    06-08-2022   HQIC                          1993.498
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   5076.044      0.000       1.000       1.000
# ma.L1         -0.8506      0.026    -32.442      0.000      -0.902      -0.799
# ma.L2         -0.0756      0.060     -1.253      0.210      -0.194       0.043
# ma.L3         -0.0412      0.074     -0.558      0.577      -0.186       0.104
# ma.L4         -0.0448      0.117     -0.383      0.702      -0.274       0.185
# ma.L5          0.0214      0.099      0.216      0.829      -0.173       0.216
# sigma2         2.2866      0.040     57.119      0.000       2.208       2.365
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             35310.28
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             5.00
# Prob(H) (two-sided):                  0.45   Kurtosis:                        41.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 5 ,) est :  0.815839084867915
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 6)   Log Likelihood                -981.589
# Date:                Fri, 17 May 2024   AIC                           1979.177
# Time:                        22:19:05   BIC                           2013.450
# Sample:                    06-08-2022   HQIC                          1992.586
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   4223.583      0.000       0.999       1.000
# ma.L1         -0.8236      0.027    -31.079      0.000      -0.876      -0.772
# ma.L2         -0.1028      0.061     -1.675      0.094      -0.223       0.017
# ma.L3         -0.0336      0.073     -0.457      0.647      -0.178       0.110
# ma.L4         -0.0578      0.109     -0.528      0.597      -0.272       0.157
# ma.L5         -0.0633      0.105     -0.602      0.547      -0.269       0.143
# ma.L6          0.0925      0.067      1.373      0.170      -0.040       0.225
# sigma2         2.2674      0.055     40.881      0.000       2.159       2.376
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):             32871.80
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             4.86
# Prob(H) (two-sided):                  0.39   Kurtosis:                        40.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 6 ,) est :  0.8251143140080415
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 7)   Log Likelihood                -976.435
# Date:                Fri, 17 May 2024   AIC                           1970.869
# Time:                        22:19:07   BIC                           2009.426
# Sample:                    06-08-2022   HQIC                          1985.954
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   5376.472      0.000       1.000       1.000
# ma.L1         -0.8367      0.030    -28.063      0.000      -0.895      -0.778
# ma.L2         -0.1145      0.066     -1.739      0.082      -0.244       0.015
# ma.L3         -0.0152      0.073     -0.209      0.834      -0.157       0.127
# ma.L4         -0.0553      0.097     -0.569      0.569      -0.246       0.135
# ma.L5         -0.0482      0.089     -0.541      0.589      -0.223       0.127
# ma.L6          0.2222      0.064      3.466      0.001       0.097       0.348
# ma.L7         -0.1439      0.041     -3.546      0.000      -0.223      -0.064
# sigma2         2.2229      0.058     38.646      0.000       2.110       2.336
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             27429.89
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             4.66
# Prob(H) (two-sided):                  0.54   Kurtosis:                        36.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 7 ,) est :  0.8116389700504417
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(1, 0, 8)   Log Likelihood                -976.418
# Date:                Fri, 17 May 2024   AIC                           1972.835
# Time:                        22:19:09   BIC                           2015.677
# Sample:                    06-08-2022   HQIC                          1989.596
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.000   5373.525      0.000       1.000       1.000
# ma.L1         -0.8369      0.031    -27.174      0.000      -0.897      -0.777
# ma.L2         -0.1159      0.066     -1.747      0.081      -0.246       0.014
# ma.L3         -0.0147      0.073     -0.202      0.840      -0.157       0.128
# ma.L4         -0.0547      0.097     -0.563      0.573      -0.245       0.136
# ma.L5         -0.0471      0.089     -0.529      0.596      -0.222       0.127
# ma.L6          0.2239      0.064      3.485      0.000       0.098       0.350
# ma.L7         -0.1384      0.067     -2.071      0.038      -0.269      -0.007
# ma.L8         -0.0080      0.057     -0.140      0.889      -0.120       0.104
# sigma2         2.2227      0.058     38.154      0.000       2.108       2.337
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             27349.64
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             4.65
# Prob(H) (two-sided):                  0.54   Kurtosis:                        36.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 1 , 8 ,) est :  0.8105982772885886
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 1)   Log Likelihood                -984.436
# Date:                Fri, 17 May 2024   AIC                           1976.873
# Time:                        22:19:10   BIC                           1994.009
# Sample:                    06-08-2022   HQIC                          1983.577
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1499      0.020     57.906      0.000       1.111       1.189
# ar.L2         -0.1500      0.020     -7.567      0.000      -0.189      -0.111
# ma.L1         -0.9916      0.011    -93.109      0.000      -1.012      -0.971
# sigma2         2.2915      0.034     67.607      0.000       2.225       2.358
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             35145.71
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             5.00
# Prob(H) (two-sided):                  0.47   Kurtosis:                        41.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 1 ,) est :  0.8191329907014312
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 2)   Log Likelihood                -989.607
# Date:                Fri, 17 May 2024   AIC                           1989.214
# Time:                        22:19:11   BIC                           2010.634
# Sample:                    06-08-2022   HQIC                          1997.594
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0229      0.060      0.384      0.701      -0.094       0.140
# ar.L2          0.9766      0.059     16.414      0.000       0.860       1.093
# ma.L1          0.0039      0.052      0.076      0.939      -0.098       0.106
# ma.L2         -0.9698      0.044    -22.101      0.000      -1.056      -0.884
# sigma2         2.3376      0.039     60.245      0.000       2.262       2.414
# ===================================================================================
# Ljung-Box (L1) (Q):                   8.92   Jarque-Bera (JB):             35724.86
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             5.14
# Prob(H) (two-sided):                  0.99   Kurtosis:                        41.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 2 ,) est :  0.8255835787686261
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 3)   Log Likelihood                -983.027
# Date:                Fri, 17 May 2024   AIC                           1978.055
# Time:                        22:19:12   BIC                           2003.759
# Sample:                    06-08-2022   HQIC                          1988.111
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1270      0.188      0.676      0.499      -0.241       0.495
# ar.L2          0.8728      0.188      4.645      0.000       0.505       1.241
# ma.L1          0.0338      0.199      0.170      0.865      -0.356       0.423
# ma.L2         -0.8471      0.179     -4.741      0.000      -1.197      -0.497
# ma.L3         -0.1676      0.035     -4.732      0.000      -0.237      -0.098
# sigma2         2.2794      0.044     52.321      0.000       2.194       2.365
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             33583.25
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.93
# Prob(H) (two-sided):                  0.45   Kurtosis:                        40.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 3 ,) est :  0.8201061574697244
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 4)   Log Likelihood                -983.018
# Date:                Fri, 17 May 2024   AIC                           1980.037
# Time:                        22:19:13   BIC                           2010.026
# Sample:                    06-08-2022   HQIC                          1991.769
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1288      0.241      0.535      0.593      -0.343       0.601
# ar.L2          0.8710      0.241      3.620      0.000       0.399       1.343
# ma.L1          0.0324      0.240      0.135      0.893      -0.438       0.503
# ma.L2         -0.8512      0.199     -4.277      0.000      -1.241      -0.461
# ma.L3         -0.1687      0.042     -4.001      0.000      -0.251      -0.086
# ma.L4          0.0068      0.064      0.107      0.915      -0.118       0.131
# sigma2         2.2796      0.050     45.759      0.000       2.182       2.377
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             33443.60
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.93
# Prob(H) (two-sided):                  0.46   Kurtosis:                        40.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 4 ,) est :  0.8206840218304611
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 5)   Log Likelihood                -981.064
# Date:                Fri, 17 May 2024   AIC                           1978.129
# Time:                        22:19:14   BIC                           2012.402
# Sample:                    06-08-2022   HQIC                          1991.537
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1675      0.183      0.915      0.360      -0.191       0.526
# ar.L2          0.8324      0.183      4.548      0.000       0.474       1.191
# ma.L1          0.0097      0.184      0.053      0.958      -0.351       0.371
# ma.L2         -0.8020      0.156     -5.155      0.000      -1.107      -0.497
# ma.L3         -0.1139      0.065     -1.742      0.081      -0.242       0.014
# ma.L4          0.0070      0.057      0.122      0.903      -0.105       0.119
# ma.L5         -0.0874      0.063     -1.392      0.164      -0.210       0.036
# sigma2         2.2616      0.055     41.485      0.000       2.155       2.368
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):             32595.94
# Prob(Q):                              0.74   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.85
# Prob(H) (two-sided):                  0.44   Kurtosis:                        39.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 5 ,) est :  0.8074702999773486
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 6)   Log Likelihood                -977.640
# Date:                Fri, 17 May 2024   AIC                           1973.279
# Time:                        22:19:16   BIC                           2011.837
# Sample:                    06-08-2022   HQIC                          1988.364
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3507      0.228      1.540      0.124      -0.096       0.797
# ar.L2          0.6492      0.228      2.850      0.004       0.203       1.096
# ma.L1         -0.1759      0.230     -0.764      0.445      -0.628       0.276
# ma.L2         -0.6389      0.197     -3.241      0.001      -1.025      -0.253
# ma.L3         -0.1010      0.070     -1.451      0.147      -0.237       0.035
# ma.L4         -0.0777      0.096     -0.808      0.419      -0.266       0.111
# ma.L5         -0.1131      0.060     -1.879      0.060      -0.231       0.005
# ma.L6          0.1248      0.077      1.611      0.107      -0.027       0.277
# sigma2         2.2338      0.063     35.543      0.000       2.111       2.357
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):             29775.01
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             4.74
# Prob(H) (two-sided):                  0.41   Kurtosis:                        38.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 6 ,) est :  0.8232837811179544
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 7)   Log Likelihood                -976.259
# Date:                Fri, 17 May 2024   AIC                           1972.518
# Time:                        22:19:17   BIC                           2015.360
# Sample:                    06-08-2022   HQIC                          1989.279
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.5186      0.196      7.758      0.000       1.135       1.902
# ar.L2         -0.5187      0.196     -2.650      0.008      -0.902      -0.135
# ma.L1         -1.3533      0.213     -6.362      0.000      -1.770      -0.936
# ma.L2          0.3131      0.206      1.519      0.129      -0.091       0.717
# ma.L3          0.0440      0.097      0.455      0.649      -0.146       0.233
# ma.L4         -0.0394      0.121     -0.326      0.745      -0.277       0.198
# ma.L5         -0.0147      0.126     -0.116      0.907      -0.262       0.233
# ma.L6          0.2350      0.091      2.572      0.010       0.056       0.414
# ma.L7         -0.1789      0.038     -4.670      0.000      -0.254      -0.104
# sigma2         2.2240      0.055     40.258      0.000       2.116       2.332
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):             27278.67
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.63
# Prob(H) (two-sided):                  0.46   Kurtosis:                        36.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 7 ,) est :  0.8075958683018954
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(2, 0, 8)   Log Likelihood                -975.779
# Date:                Fri, 17 May 2024   AIC                           1973.559
# Time:                        22:19:19   BIC                           2020.684
# Sample:                    06-08-2022   HQIC                          1991.995
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0246      0.060      0.413      0.680      -0.092       0.142
# ar.L2          0.9752      0.060     16.364      0.000       0.858       1.092
# ma.L1          0.1452      0.064      2.268      0.023       0.020       0.271
# ma.L2         -0.9341      0.061    -15.312      0.000      -1.054      -0.815
# ma.L3         -0.1304      0.064     -2.047      0.041      -0.255      -0.006
# ma.L4         -0.0687      0.096     -0.715      0.474      -0.257       0.120
# ma.L5         -0.0994      0.094     -1.060      0.289      -0.283       0.084
# ma.L6          0.1694      0.084      2.027      0.043       0.006       0.333
# ma.L7          0.0798      0.079      1.006      0.314      -0.076       0.235
# ma.L8         -0.1428      0.043     -3.318      0.001      -0.227      -0.058
# sigma2         2.2196      0.061     36.464      0.000       2.100       2.339
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):             27594.92
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             4.66
# Prob(H) (two-sided):                  0.52   Kurtosis:                        36.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 2 , 8 ,) est :  0.8142414683548865
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(3, 0, 1)   Log Likelihood                -984.144
# Date:                Fri, 17 May 2024   AIC                           1978.287
# Time:                        22:19:20   BIC                           1999.708
# Sample:                    06-08-2022   HQIC                          1986.668
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1461      0.026     43.704      0.000       1.095       1.197
# ar.L2         -0.1124      0.068     -1.651      0.099      -0.246       0.021
# ar.L3         -0.0337      0.048     -0.704      0.481      -0.128       0.060
# ma.L1         -0.9928      0.010    -94.637      0.000      -1.013      -0.972
# sigma2         2.2887      0.033     68.579      0.000       2.223       2.354
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             35418.11
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             5.01
# Prob(H) (two-sided):                  0.46   Kurtosis:                        41.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 3 , 1 ,) est :  0.814529957244535
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(3, 0, 2)   Log Likelihood                -984.293
# Date:                Fri, 17 May 2024   AIC                           1980.587
# Time:                        22:19:21   BIC                           2006.292
# Sample:                    06-08-2022   HQIC                          1990.643
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1591      0.079      2.022      0.043       0.005       0.313
# ar.L2          0.9855      0.092     10.695      0.000       0.805       1.166
# ar.L3         -0.1448      0.026     -5.481      0.000      -0.197      -0.093
# ma.L1        9.95e-05      0.072      0.001      0.999      -0.141       0.141
# ma.L2         -0.9822      0.069    -14.167      0.000      -1.118      -0.846
# sigma2         2.2905      0.037     61.940      0.000       2.218       2.363
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             35262.15
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             5.00
# Prob(H) (two-sided):                  0.47   Kurtosis:                        41.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 3 , 2 ,) est :  0.8204260182134777
# ...
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9908      1.126     -0.880      0.379      -3.199       1.217
# ar.L2          0.5756      0.251      2.295      0.022       0.084       1.067
# ar.L3          1.2001      0.868      1.382      0.167      -0.502       2.902
# ar.L4          0.3253      0.621      0.524      0.600      -0.892       1.543
# ar.L5         -0.2285      0.221     -1.033      0.302      -0.662       0.205
# ar.L6         -0.0022      0.155     -0.014      0.989      -0.306       0.302
# ar.L7          0.0867      0.179      0.483      0.629      -0.265       0.438
# ar.L8          0.0329      0.122      0.270      0.787      -0.205       0.271
# ma.L1          1.1628      1.122      1.036      0.300      -1.037       3.363
# ma.L2         -0.3465      0.403     -0.861      0.389      -1.135       0.442
# ma.L3         -1.2109      0.742     -1.632      0.103      -2.665       0.243
# ma.L4         -0.5429      0.709     -0.765      0.444      -1.933       0.847
# sigma2         2.2307      0.065     34.165      0.000       2.103       2.359
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             30132.51
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.76
# Prob(H) (two-sided):                  0.44   Kurtosis:                        38.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 8 , 4 ,) est :  0.8243923756240259
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(8, 0, 5)   Log Likelihood                -975.495
# Date:                Fri, 17 May 2024   AIC                           1978.990
# Time:                        22:20:55   BIC                           2038.968
# Sample:                    06-08-2022   HQIC                          2002.455
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.0383      0.296     -3.504      0.000      -1.619      -0.457
# ar.L2         -0.3035      0.208     -1.458      0.145      -0.712       0.105
# ar.L3          1.0933      0.089     12.265      0.000       0.919       1.268
# ar.L4          1.0159      0.359      2.827      0.005       0.312       1.720
# ar.L5          0.2245      0.251      0.894      0.371      -0.267       0.716
# ar.L6         -0.1372      0.083     -1.658      0.097      -0.299       0.025
# ar.L7          0.0168      0.112      0.149      0.881      -0.203       0.237
# ar.L8          0.1282      0.084      1.535      0.125      -0.036       0.292
# ma.L1          1.2138      0.297      4.083      0.000       0.631       1.797
# ma.L2          0.5515      0.253      2.183      0.029       0.056       1.047
# ma.L3         -0.9443      0.044    -21.355      0.000      -1.031      -0.858
# ma.L4         -1.1716      0.294     -3.983      0.000      -1.748      -0.595
# ma.L5         -0.5601      0.246     -2.273      0.023      -1.043      -0.077
# sigma2         2.2096      0.066     33.245      0.000       2.079       2.340
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             28694.85
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             4.68
# Prob(H) (two-sided):                  0.50   Kurtosis:                        37.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 8 , 5 ,) est :  0.8307007707401483
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(8, 0, 6)   Log Likelihood                -975.555
# Date:                Fri, 17 May 2024   AIC                           1981.109
# Time:                        22:20:57   BIC                           2045.371
# Sample:                    06-08-2022   HQIC                          2006.250
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9162      0.428     -2.139      0.032      -1.756      -0.077
# ar.L2         -0.5062      0.183     -2.765      0.006      -0.865      -0.147
# ar.L3          0.3057      0.121      2.518      0.012       0.068       0.544
# ar.L4          0.8335      0.247      3.380      0.001       0.350       1.317
# ar.L5          0.9182      0.306      2.998      0.003       0.318       1.519
# ar.L6          0.4574      0.269      1.703      0.089      -0.069       0.984
# ar.L7         -0.1321      0.079     -1.677      0.094      -0.286       0.022
# ar.L8          0.0384      0.101      0.379      0.705      -0.160       0.237
# ma.L1          1.0866      0.425      2.554      0.011       0.253       1.920
# ma.L2          0.7379      0.232      3.178      0.001       0.283       1.193
# ma.L3         -0.1183      0.164     -0.723      0.469      -0.439       0.202
# ma.L4         -0.8221      0.159     -5.181      0.000      -1.133      -0.511
# ma.L5         -1.1294      0.287     -3.941      0.000      -1.691      -0.568
# ma.L6         -0.6376      0.333     -1.915      0.056      -1.290       0.015
# sigma2         2.2278      0.073     30.660      0.000       2.085       2.370
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             29389.70
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.71
# Prob(H) (two-sided):                  0.47   Kurtosis:                        38.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 8 , 6 ,) est :  0.8235726772920469
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(8, 0, 7)   Log Likelihood                -975.987
# Date:                Fri, 17 May 2024   AIC                           1983.973
# Time:                        22:21:01   BIC                           2052.519
# Sample:                    06-08-2022   HQIC                          2010.790
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8242      1.881     -0.438      0.661      -4.510       2.862
# ar.L2         -0.0656      2.430     -0.027      0.978      -4.828       4.697
# ar.L3          0.8370      1.665      0.503      0.615      -2.426       4.100
# ar.L4          0.9203      1.743      0.528      0.598      -2.497       4.337
# ar.L5          0.1141      2.564      0.044      0.965      -4.911       5.139
# ar.L6         -0.0923      1.800     -0.051      0.959      -3.620       3.436
# ar.L7          0.0642      0.690      0.093      0.926      -1.288       1.417
# ar.L8          0.0460      0.225      0.204      0.838      -0.396       0.488
# ma.L1          0.9926      1.887      0.526      0.599      -2.706       4.691
# ma.L2          0.2768      2.713      0.102      0.919      -5.040       5.594
# ma.L3         -0.7488      2.039     -0.367      0.713      -4.746       3.248
# ma.L4         -1.0504      1.602     -0.656      0.512      -4.189       2.089
# ma.L5         -0.3887      2.623     -0.148      0.882      -5.531       4.753
# ma.L6          0.0329      2.161      0.015      0.988      -4.203       4.268
# ma.L7         -0.0588      0.994     -0.059      0.953      -2.006       1.889
# sigma2         2.2147      0.072     30.774      0.000       2.074       2.356
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             29629.51
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             4.71
# Prob(H) (two-sided):                  0.48   Kurtosis:                        38.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 8 , 7 ,) est :  0.8195716305625901
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Values   No. Observations:                  536
# Model:               SARIMAX(8, 0, 8)   Log Likelihood                -976.780
# Date:                Fri, 17 May 2024   AIC                           1987.561
# Time:                        22:21:04   BIC                           2060.391
# Sample:                    06-08-2022   HQIC                          2016.054
#                          - 11-25-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4866      1.525     -0.319      0.750      -3.475       2.502
# ar.L2          0.1208      1.635      0.074      0.941      -3.084       3.326
# ar.L3          0.0537      1.407      0.038      0.970      -2.705       2.812
# ar.L4          0.4165      0.770      0.541      0.589      -1.093       1.926
# ar.L5          0.4949      1.063      0.466      0.641      -1.588       2.578
# ar.L6          0.0717      1.129      0.064      0.949      -2.140       2.284
# ar.L7          0.0726      0.846      0.086      0.932      -1.586       1.732
# ar.L8          0.2521      0.512      0.492      0.622      -0.751       1.255
# ma.L1          0.6592      1.531      0.431      0.667      -2.342       3.660
# ma.L2          0.0377      1.859      0.020      0.984      -3.605       3.681
# ma.L3         -0.0110      1.533     -0.007      0.994      -3.016       2.994
# ma.L4         -0.4405      0.794     -0.555      0.579      -1.997       1.116
# ma.L5         -0.6659      1.071     -0.622      0.534      -2.765       1.434
# ma.L6         -0.1095      1.422     -0.077      0.939      -2.896       2.677
# ma.L7         -0.0685      1.111     -0.062      0.951      -2.247       2.110
# ma.L8         -0.2461      0.708     -0.348      0.728      -1.634       1.142
# sigma2         2.2248      0.071     31.198      0.000       2.085       2.365
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):             27957.79
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             4.66
# Prob(H) (two-sided):                  0.45   Kurtosis:                        37.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# La rmse du modèle ARMA( 8 , 8 ,) est :  0.8096631729404594
# C:\Users\yanni\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ## Prévisions à partir de notre modèle

# %% [markdown]
# ### Génération des prédictions

# %%
pred = Auto_arma_model.predict(len(test.index))
pred
# Out:
# 2023-11-26    1.143061
# 2023-11-27    1.133954
# 2023-11-28    1.132547
# 2023-11-29    1.132330
# 2023-11-30    1.132296
#                 ...
# 2024-04-04    1.132290
# 2024-04-05    1.132290
# 2024-04-06    1.132290
# 2024-04-07    1.132290
# 2024-04-08    1.132290
# Freq: D, Length: 135, dtype: float64

# %%
pred2 = ARMA_result.predict(start=test.index[0], end=test.index[-1])
pred2
# Out:
# 2023-11-26    1.202517
# 2023-11-27    1.209009
# 2023-11-28    1.164739
# 2023-11-29    1.125703
# 2023-11-30    1.120288
#                 ...
# 2024-04-04    1.192248
# 2024-04-05    1.192208
# 2024-04-06    1.192168
# 2024-04-07    1.192128
# 2024-04-08    1.192088
# Freq: D, Name: predicted_mean, Length: 135, dtype: float64

# %%
resid = ARMA_result.resid
resid.plot()
plt.show()

# %% [markdown]
# ### Visualisation des valeurs prédites et des valeurs réelles

# %%
plt.figure(figsize=(14,6))
#plt.plot(test, label='Valeurs réelles')
plt.plot(pred2, label='Valeurs prédites')
plt.xlabel('Dates')
plt.ylabel('Ratio')
#plt.ylim(0,2)
plt.legend()
plt.show()

# %% [markdown]
# ### Validation du modèle

# %%
error_test = test.values-pred.values
rmse_test = np.sqrt((error_test**2).mean())
error_train = train.values-pred2.values
rmse_train = np.sqrt((error_train**2).mean())
print('RMSE sur les données d\'entraînement : ', rmse_train)
print('RMSE sur les données de test : ', rmse_test)
# Out:
# RMSE sur les données d'entraînement :  1.7892857023022806
# RMSE sur les données de test :  0.7900030336849901

# %% [markdown]
# ### Boosting de notre modèle

# %% [markdown]
# #### Création des caractéristiques

# %%
def create_feature(df):
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

# %%
train_f = create_feature(train)
test_f = create_feature(test)

FEATURES = ['dayofyear', 'dayofweek', 'month', 'year']
TARGET = 'Values'

X_train = train_f[FEATURES]
y_train = train_f[TARGET]

X_test = test_f[FEATURES]
y_test = test_f[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=50)
# Out:
# [0]	validation_0-rmse:1.64949	validation_1-rmse:0.92461
# [50]	validation_0-rmse:1.51159	validation_1-rmse:0.83612
# [100]	validation_0-rmse:1.44708	validation_1-rmse:0.80652
# C:\Users\yanni\anaconda3\lib\site-packages\xgboost\core.py:160: UserWarning: [22:29:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [150]	validation_0-rmse:1.41367	validation_1-rmse:0.79704
# [200]	validation_0-rmse:1.39208	validation_1-rmse:0.79440
# [250]	validation_0-rmse:1.37071	validation_1-rmse:0.79373
# [274]	validation_0-rmse:1.35634	validation_1-rmse:0.79487
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, objective='reg:linear', ...)

# %%
test['prediction'] = reg.predict(X_test)
test.describe()
# Out:
# C:\Users\yanni\AppData\Local\Temp\ipykernel_12372\4051859114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = reg.predict(X_test)
#            Values  prediction
# count  135.000000  135.000000
# mean     1.003009    0.882340
# std      0.782239    0.180448
# min      0.185000    0.587632
# 25%      0.678500    0.759103
# 50%      0.795000    0.892848
# 75%      1.022500    0.959232
# max      6.125574    1.393954

# %%
plt.figure(figsize=(14,6))
plt.plot(test['Values'], label='Valeurs réelles')
plt.plot(test['prediction'], label='Valeurs prédites')
plt.xlabel('Dates')
plt.ylabel('Ratio')
plt.legend()
plt.show()

# %%
error_test_2 = test['Values']-test['prediction']
rmse_test_2 = np.sqrt((error_test**2).mean())
#error_train = train.values-pred2.values
#rmse_train = np.sqrt((error_train**2).mean())
#print('RMSE sur les données d\'entraînement : ', rmse_train)
print('RMSE  : ', rmse_test_2)
# Out:
# RMSE  :  0.7900030336849901

# %% [markdown]
# ### Interprétation des résultats

# %%
Feat = create_feature(Ratio)
fig, ax = plt.subplots(figsize=(14, 6))
sns.boxplot(data=Feat, x='month', y='Values')
ax.set_title('Ratio par mois')
plt.show()

# %% [markdown]
# #### Visualisation des données de ratio sur les températures

# %%
#Jointure de nos données

data = pd.merge(Ratio, Tj, left_on='Temps', right_on='Date')
data.head()
# Out:
#      Values Temperature
# 0  4.989118   16.360245
# 1  0.567312   15.875245
# 2  0.669030   17.516493
# 3  0.680712    20.63733
# 4  0.528097   22.341078

# %%
data['Temperature'] = data['Temperature'].astype(float)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671 entries, 0 to 670
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Values       671 non-null    float64
#  1   Temperature  671 non-null    float64
# dtypes: float64(2)
# memory usage: 15.7 KB

# %%
plt.figure(figsize=(14,6))
plt.plot(data.index, data['Values'], label='Ratio')
plt.plot(data.index, data['Temperature'], label='Températures')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %% [markdown]
# #### Importance de nos caractéristiques

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature importance')
plt.show()
